# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1  West Indies      England   0.1     4                0
# 1              1  West Indies      England   0.2     0                0
# 2              1  West Indies      England   0.3     1                0
# 3              1  West Indies      England   0.4     1                0
# 4              1  West Indies      England   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 402726      3344    Sri Lanka    Australia  19.3     1                0
# 402727      3344    Sri Lanka    Australia  19.4     0                0
# 402728      3344    Sri Lanka    Australia  19.5     0      DM de Silva
# 402729      3344    Sri Lanka    Australia  19.6     2                0
# 402730      3344    Sri Lanka    Australia  19.7     1                0
#
#                      city                venue
# 0       Chester-le-Street     Riverside Ground
# ...

# %%
#we need bowling team
#batting team
#city
#current score
#ball left
#last 5 over
#crr
#wickets left

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8171
# venue                  0
# dtype: int64

# %%
df.shape
# Out:
# (110049, 8)

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1328
# Sydney Cricket Ground                       621
# Adelaide Oval                               373
# Harare Sports Club                          372
# Sylhet International Cricket Stadium        128
# Sharjah Cricket Stadium                     127
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x : x[0]),df['city'])

# %%
df['city'] = cities

# %%
df['city'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns = ['venue'], inplace = True)

# %%
eligible_cities= df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df[df['city'].isin(eligible_cities)]
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1  West Indies      England   0.1     4                0
# 1              1  West Indies      England   0.2     0                0
# 2              1  West Indies      England   0.3     1                0
# 3              1  West Indies      England   0.4     1                0
# 4              1  West Indies      England   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 402726      3344    Sri Lanka    Australia  19.3     1                0
# 402727      3344    Sri Lanka    Australia  19.4     0                0
# 402728      3344    Sri Lanka    Australia  19.5     0      DM de Silva
# 402729      3344    Sri Lanka    Australia  19.6     2                0
# 402730      3344    Sri Lanka    Australia  19.7     1                0
#
#                      city
# 0       Chester-le-Street
# 1       Chester-le-Street
# ...

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1  West Indies      England   0.1     4                0
# 1              1  West Indies      England   0.2     0                0
# 2              1  West Indies      England   0.3     1                0
# 3              1  West Indies      England   0.4     1                0
# 4              1  West Indies      England   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 402726      3344    Sri Lanka    Australia  19.3     1                0
# 402727      3344    Sri Lanka    Australia  19.4     0                0
# 402728      3344    Sri Lanka    Australia  19.5     0      DM de Silva
# 402729      3344    Sri Lanka    Australia  19.6     2                0
# 402730      3344    Sri Lanka    Australia  19.7     1                0
#
#                      city
# 0       Chester-le-Street
# 1       Chester-le-Street
# ...

# %%
df.sample()
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 158820      1323  New Zealand     Pakistan  18.6     2                0
#
#             city
# 158820  Hamilton

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df.iloc[0:125,:]
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           1  West Indies      England   0.1     4                0
# 1           1  West Indies      England   0.2     0                0
# 2           1  West Indies      England   0.3     1                0
# 3           1  West Indies      England   0.4     1                0
# 4           1  West Indies      England   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 120         1  West Indies      England  18.6     0                0
# 121         1  West Indies      England  19.1     0                0
# 122         1  West Indies      England  19.2     0        JE Taylor
# 123         1  West Indies      England  19.3     1                0
# 124         1  West Indies      England  19.4     6                0
#
#                   city  current_score
# 0    Chester-le-Street              4
# 1    Chester-le-Street              4
# ...

# %%
df['over'] = df['ball'].apply(lambda x : str(x).split('.')[0])
df['ball_no'] = df['ball'].apply(lambda x : str(x).split('.')[1])

# %%
df['balls_bowled'] = (df['over'].astype(int) * 6) + df['ball_no'].astype(int)

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x : 0 if x < 0 else x)

# %%
df.sample()
# Out:
#        match_id batting_team bowling_team  ball  runs player_dismissed  \
# 14142       118  New Zealand        India  18.5     1                0
#
#            city  current_score over ball_no  balls_bowled  balls_left
# 14142  Auckland            150   18       5           113           7

# %%
df[df['balls_bowled'] > 120].sample()
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 384975      3196    Australia  West Indies  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 384975  Mirpur            173   19       7           121           0

# %%
print(df['player_dismissed'].unique())
# Out:
# ['0' 'CH Gayle' 'E Lewis' 'MN Samuels' 'KA Pollard' 'CAK Walton'
#  'CR Brathwaite' 'SP Narine' 'R Powell' 'JE Taylor' 'KL Rahul' 'V Kohli'
#  'Yuvraj Singh' 'SK Raina' 'MK Pandey' 'HH Pandya' 'Parvez Rasool'
#  'A Mishra' 'MS Dhoni' 'J Charles' 'AD Russell' 'LMP Simmons'
#  'ADS Fletcher' 'DJ Bravo' 'S Badree' 'N Pooran' 'Sharjeel Khan'
#  'Babar Azam' 'Khalid Latif' 'Shoaib Malik' 'C Munro' 'MJ Guptill'
#  'TC Bruce' 'KS Williamson' 'TA Blundell' 'LRPL Taylor' 'MJ Santner'
#  'TG Southee' 'IS Sodhi' 'JJ Roy' 'AD Hales' 'EJG Morgan' 'JC Buttler'
#  'SW Billings' 'DJ Malan' 'DJ Willey' 'AU Rashid' 'TK Curran' 'JM Vince'
#  'C de Grandhomme' 'MS Chapman' 'TL Seifert' 'LA Dawson' 'HM Amla'
#  'AB de Villiers' 'JP Duminy' 'Q de Kock' 'M Mosehle' 'JO Holder'
#  'Kamran Akmal' 'Ahmed Shehzad' 'Fakhar Zaman' 'Sarfraz Ahmed'
#  'Sohail Tanvir' 'Imad Wasim' 'Wahab Riaz' 'Shadab Khan' 'Tamim Iqbal'
#  'Sabbir Rahman' 'Soumya Sarkar' 'Mushfiqur Rahim' 'Shakib Al Hasan'
# ...

# %%
temp = df.copy()

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x : 0 if x == '0' else 1)
#df['player_dismissed'] = df['player_dismissed'].astype(int)
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df.iloc[125:300,:]
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 125         1  West Indies      England  19.5     1                 1
# 126         1  West Indies      England  19.6     1                 1
# 127         2        India      England   0.1     0                 1
# 128         2        India      England   0.2     0                 1
# 129         2        India      England   0.3     4                 1
# ..        ...          ...          ...   ...   ...               ...
# 295         3        India      England   6.4     3                 1
# 296         3        India      England   6.5     1                 1
# 297         3        India      England   6.6     1                 1
# 298         3        India      England   6.7     0                 1
# 299         3        India      England   7.1     1                 1
#
#                   city  current_score over ball_no  balls_bowled  balls_left
# ...

# %%
temp.sample()
# Out:
#         match_id  batting_team bowling_team  ball  runs player_dismissed  \
# 375755      3120  South Africa  New Zealand  18.4     4                0
#
#                   city  current_score over ball_no  balls_bowled  balls_left
# 375755  Port Elizabeth            154   18       4           112           8

# %%
df['player_dismissed'].value_counts()
# Out:
# player_dismissed
# 0    104107
# 1      5942
# Name: count, dtype: int64

# %%
df.groupby('match_id')['player_dismissed'].sum().sort_values(ascending=False).head(20)
# Out:
# match_id
# 1817    10
# 2472    10
# 1985    10
# 1986    10
# 2120    10
# 2151    10
# 2155    10
# 157     10
# 2169    10
# 132     10
# 2344    10
# 2345    10
# 2350    10
# 2351    10
# 2447    10
# 2480    10
# 1788    10
# 2528    10
# 2545    10
# 116     10
# Name: player_dismissed, dtype: int64

# %%
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# %%
df.sample()
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 183688      1530        India   Bangladesh  15.3     1                 4
#
#                city  current_score over ball_no  balls_bowled  balls_left
# 183688  North Sound            137   15       3            93          27

# %%
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df.sample()
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 371799      3086  West Indies    Sri Lanka  16.2     1                 5
#
#            city  current_score over ball_no  balls_bowled  balls_left  \
# 371799  Colombo             91   16       2            98          22
#
#         wickets_left
# 371799             5

# %%
df['crr'] = (df['current_score'] * 6) / df['balls_bowled']

# %%
df.sample()
# Out:
#         match_id batting_team  bowling_team  ball  runs  player_dismissed  \
# 393448      3266        India  South Africa   8.5     1                 4
#
#            city  current_score over ball_no  balls_bowled  balls_left  \
# 393448  Cuttack             46    8       5            53          67
#
#         wickets_left       crr
# 393448             6  5.207547

# %%
groups = df.groupby('match_id')

# %%
match_ids = df['match_id'].unique()
last_five = []

for match_id in match_ids:
    temp = groups.get_group(match_id)['runs'].rolling(window=30).sum()
    last_five.extend(temp.tolist())

# %%
df['last_five'] = last_five

# %%
df.sample()
# Out:
#       match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 8536        70   Bangladesh        India  17.2     0                 6
#
#          city  current_score over ball_no  balls_bowled  balls_left  \
# 8536  Colombo            119   17       2           104          16
#
#       wickets_left       crr  last_five
# 8536             4  6.865385       30.0

# %%
#df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five']]

# %%
fdf = df.groupby('match_id')['runs'].sum().reset_index().merge(df,on = 'match_id')

# %%
fdf.sample()
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 39298       981     166     Pakistan      England  16.5       1
#
#        player_dismissed     city  current_score over ball_no  balls_bowled  \
# 39298                 1  Karachi            136   16       5           101
#
#        balls_left  wickets_left       crr  last_five  final_score
# 39298          19             9  8.079208       38.0          NaN

# %%
final_df = fdf[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.sample()
# Out:
#       batting_team bowling_team    city  current_score  balls_left  \
# 18098   Bangladesh     Pakistan  Lahore            117          14
#
#        wickets_left       crr  last_five  runs_x
# 18098             6  6.622642       38.0     136

# %%
final_df.dropna(inplace = True)
# Out:
# C:\Users\KASHIF\AppData\Local\Temp\ipykernel_12760\1587496580.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace = True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df.shape
# Out:
# (83698, 9)

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#         batting_team  bowling_team          city  current_score  balls_left  \
# 49603    West Indies  South Africa   North Sound            117          18
# 27681   South Africa     Australia     Abu Dhabi             83          35
# 42958    New Zealand         India       Lucknow             93           5
# 104062         India     Australia     Melbourne             84          65
# 82756       Pakistan     Australia    Birmingham            104          43
# ...              ...           ...           ...            ...         ...
# 9363      Bangladesh   West Indies    Lauderhill             71          85
# 91309    West Indies     Australia      Barbados            121          44
# 18273      Australia         India        Sydney             55          88
# 32526          India  South Africa         Delhi            211           0
# 69665   South Africa     Australia  Johannesburg            105          48
#
#         wickets_left        crr  last_five  runs_x
# ...

# %%
X = final_df.drop(columns = ['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, random_state = 1)

# %%
X.shape
# Out:
# (83698, 8)

# %%
y_train.shape
# Out:
# (66958,)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# %%
X_train
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 81519      Pakistan  South Africa      St Lucia             72          51
# 4127          India     Australia      Guwahati             85          29
# 71305   New Zealand         India  Johannesburg            164          13
# 86563     Australia         India        Sydney             81          58
# 73952       England   New Zealand  Christchurch             67          83
# ...             ...           ...           ...            ...         ...
# 16457     Sri Lanka   New Zealand         Kandy             50          66
# 64776  South Africa      Pakistan        Lahore             42          78
# 30835  South Africa       England   Southampton             84          56
# 95357  South Africa     Sri Lanka    Hambantota            140          12
# 64633  South Africa      Pakistan    Rawalpindi             54          91
#
#        wickets_left        crr  last_five
# ...

# %%
trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output= False, drop = 'first'),['batting_team','bowling_team','city'])
],remainder = 'passthrough')

# %%
pipe = Pipeline(steps = [
    ('step1', trf),
    ('step2', StandardScaler()),
    ('step3', XGBRegressor(n_estimator = 1000,learning_rate = 0.2,max_depth = 12,random_state = 1))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\KASHIF\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:09:32] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:793:
# Parameters: { "n_estimator" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', StandardScaler()),
#                 ('step3',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
# ...

# %%
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9631258249282837
# 4.253983020782471

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
len(final_df['bowling_team'].unique())
# Out:
# 9

# %%
eligibe_cities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 eligibe_cities
#
# NameError: name 'eligibe_cities' is not defined

# %%
df['city'].unique()
# Out:
# array(['Chester-le-Street', 'Kanpur', 'Nagpur', 'Bangalore', 'Lauderhill',
#        'Dubai', 'Abu Dhabi', 'Sydney', 'Hobart', 'Melbourne',
#        'Wellington', 'Auckland', 'Hamilton', 'Bloemfontein',
#        'Potchefstroom', 'Barbados', 'Trinidad', 'Colombo', 'Jamaica',
#        'Nelson', 'Mount Maunganui', 'Ranchi', 'Guwahati', 'Birmingham',
#        'Manchester', 'Cardiff', 'Bristol', 'Delhi', 'Rajkot',
#        'Thiruvananthapuram', 'Lahore', 'Johannesburg', 'Centurion',
#        'Cape Town', 'Cuttack', 'Indore', 'Mumbai', 'Dhaka', 'Sylhet',
#        'Karachi', 'Harare', 'Carrara', 'Brisbane', 'St Kitts', 'Kolkata',
#        'Lucknow', 'Chennai', 'Gros Islet', 'Basseterre', 'Visakhapatnam',
#        'Bengaluru', 'Adelaide', 'Canberra', 'Perth', 'East London',
#        'Durban', 'Port Elizabeth', 'Chandigarh', 'Hyderabad',
#        'Christchurch', 'Napier', 'Providence', 'Kandy', 'Southampton',
#        'Pune', 'Dunedin', 'Paarl', 'Nottingham', 'Leeds', 'Ahmedabad',
# ...

# %%
X_train
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 81519      Pakistan  South Africa      St Lucia             72          51
# 4127          India     Australia      Guwahati             85          29
# 71305   New Zealand         India  Johannesburg            164          13
# 86563     Australia         India        Sydney             81          58
# 73952       England   New Zealand  Christchurch             67          83
# ...             ...           ...           ...            ...         ...
# 16457     Sri Lanka   New Zealand         Kandy             50          66
# 64776  South Africa      Pakistan        Lahore             42          78
# 30835  South Africa       England   Southampton             84          56
# 95357  South Africa     Sri Lanka    Hambantota            140          12
# 64633  South Africa      Pakistan    Rawalpindi             54          91
#
#        wickets_left        crr  last_five
# ...
